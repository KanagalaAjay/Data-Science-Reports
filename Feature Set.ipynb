# %%
 #df1= pd.DataFrame({'Feel':})
    
    
data=[{'Blue':4,'Red':4}
     {'Blue':4,'Yellow':3}
     {'Yellow':3,'Red':4}] 

from sklearn.feature_extraction import DictVectorizer


#numpy is building block of pandas
# pandas are used to create data frame
# Out:
#   File "<ipython-input-2-4337e527c40e>", line 5
#     {'Blue':4,'Yellow':3}
#     ^
# SyntaxError: invalid syntax

# %%
import numpy as np

dt_strings= np.array(['10-08-2018 12:30 PM',
                    '19-08-2018 12:00 PM',
                    '30-08-2018 1:30 PM'])

# %%
import pandas as pd
[pd.to_datetime(date, format='%m-%d-%Y %I:%M %p')for date in dt_strings]
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-21-792f4efbfb2c> in <module>()
#       1 import pandas as pd
# ----> 2 [pd.to_datetime(date, format='%m-%d-%Y %I:%M %p')for date in dt_strings]
#
# C:\Users\Ajay Acharya\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\pandas\core\tools\datetimes.pyc in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin)
#     516         result = _convert_listlike(arg, box, format)
#     517     else:
# --> 518         result = _convert_listlike(np.array([arg]), box, format)[0]
#     519
#     520     return result
#
# C:\Users\Ajay Acharya\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\pandas\core\tools\datetimes.pyc in _convert_listlike(arg, box, format, name, tz)
#     445                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#     446             except (ValueError, TypeError):
# --> 447                 raise e
#     448
# ...

# %%
dt_london=pd.Timestamp('2018-10-08 12:30:30', tz="Europe/London")

# %%
dt_london.tz_convert('Africa/Abidjan')
# Out:
# Timestamp('2018-10-08 11:30:30+0000', tz='Africa/Abidjan')

# %%
from pytz import all_timezones
all_timezones
# Out:
# ['Africa/Abidjan',
#  'Africa/Accra',
#  'Africa/Addis_Ababa',
#  'Africa/Algiers',
#  'Africa/Asmara',
#  'Africa/Asmera',
#  'Africa/Bamako',
#  'Africa/Bangui',
#  'Africa/Banjul',
#  'Africa/Bissau',
#  'Africa/Blantyre',
#  'Africa/Brazzaville',
#  'Africa/Bujumbura',
#  'Africa/Cairo',
#  'Africa/Casablanca',
#  'Africa/Ceuta',
#  'Africa/Conakry',
#  'Africa/Dakar',
#  'Africa/Dar_es_Salaam',
#  'Africa/Djibouti',
#  'Africa/Douala',
#  'Africa/El_Aaiun',
#  'Africa/Freetown',
#  'Africa/Gaborone',
#  'Africa/Harare',
#  'Africa/Johannesburg',
#  'Africa/Juba',
#  'Africa/Kampala',
#  'Africa/Khartoum',
#  'Africa/Kigali',
#  'Africa/Kinshasa',
#  'Africa/Lagos',
#  'Africa/Libreville',
#  'Africa/Lome',
#  'Africa/Luanda',
#  'Africa/Lubumbashi',
#  'Africa/Lusaka',
#  'Africa/Malabo',
#  'Africa/Maputo',
#  'Africa/Maseru',
#  'Africa/Mbabane',
#  'Africa/Mogadishu',
#  'Africa/Monrovia',
#  'Africa/Nairobi',
#  'Africa/Ndjamena',
#  'Africa/Niamey',
#  'Africa/Nouakchott',
# ...

# %%
import pandas as pd
df_date=pd.DataFrame()
df_date['date']=pd.date_range('1/1/2017', periods=100, freq='H')
df_date
# Out:
#                   date
# 0  2017-01-01 00:00:00
# 1  2017-01-01 01:00:00
# 2  2017-01-01 02:00:00
# 3  2017-01-01 03:00:00
# 4  2017-01-01 04:00:00
# 5  2017-01-01 05:00:00
# 6  2017-01-01 06:00:00
# 7  2017-01-01 07:00:00
# 8  2017-01-01 08:00:00
# 9  2017-01-01 09:00:00
# 10 2017-01-01 10:00:00
# 11 2017-01-01 11:00:00
# 12 2017-01-01 12:00:00
# 13 2017-01-01 13:00:00
# 14 2017-01-01 14:00:00
# 15 2017-01-01 15:00:00
# 16 2017-01-01 16:00:00
# 17 2017-01-01 17:00:00
# 18 2017-01-01 18:00:00
# 19 2017-01-01 19:00:00
# 20 2017-01-01 20:00:00
# 21 2017-01-01 21:00:00
# 22 2017-01-01 22:00:00
# 23 2017-01-01 23:00:00
# 24 2017-01-02 00:00:00
# 25 2017-01-02 01:00:00
# 26 2017-01-02 02:00:00
# 27 2017-01-02 03:00:00
# 28 2017-01-02 04:00:00
# 29 2017-01-02 05:00:00
# ..                 ...
# 70 2017-01-03 22:00:00
# 71 2017-01-03 23:00:00
# 72 2017-01-04 00:00:00
# 73 2017-01-04 01:00:00
# 74 2017-01-04 02:00:00
# 75 2017-01-04 03:00:00
# 76 2017-01-04 04:00:00
# 77 2017-01-04 05:00:00
# ...

# %%
df_date[df_date['date']>'2018-08-30']
# Out:
#          date
# 19 2018-08-31
# 20 2018-09-30
# 21 2018-10-31
# 22 2018-11-30
# 23 2018-12-31
# 24 2019-01-31
# 25 2019-02-28
# 26 2019-03-31
# 27 2019-04-30
# 28 2019-05-31
# 29 2019-06-30
# 30 2019-07-31
# 31 2019-08-31
# 32 2019-09-30
# 33 2019-10-31
# 34 2019-11-30
# 35 2019-12-31
# 36 2020-01-31
# 37 2020-02-29
# 38 2020-03-31
# 39 2020-04-30
# 40 2020-05-31
# 41 2020-06-30
# 42 2020-07-31
# 43 2020-08-31
# 44 2020-09-30
# 45 2020-10-31
# 46 2020-11-30
# 47 2020-12-31
# 48 2021-01-31
# ..        ...
# 70 2022-11-30
# 71 2022-12-31
# 72 2023-01-31
# 73 2023-02-28
# 74 2023-03-31
# 75 2023-04-30
# 76 2023-05-31
# 77 2023-06-30
# 78 2023-07-31
# 79 2023-08-31
# 80 2023-09-30
# 81 2023-10-31
# 82 2023-11-30
# 83 2023-12-31
# 84 2024-01-31
# 85 2024-02-29
# 86 2024-03-31
# 87 2024-04-30
# 88 2024-05-31
# 89 2024-06-30
# 90 2024-07-31
# 91 2024-08-31
# 92 2024-09-30
# 93 2024-10-31
# 94 2024-11-30
# 95 2024-12-31
# 96 2025-01-31
# 97 2025-02-28
# 98 2025-03-31
# 99 2025-04-30
#
# ...

# %%
df_date.head
# Out:
# <bound method DataFrame.head of                   date
# 0  2017-01-01 00:00:00
# 1  2017-01-01 01:00:00
# 2  2017-01-01 02:00:00
# 3  2017-01-01 03:00:00
# 4  2017-01-01 04:00:00
# 5  2017-01-01 05:00:00
# 6  2017-01-01 06:00:00
# 7  2017-01-01 07:00:00
# 8  2017-01-01 08:00:00
# 9  2017-01-01 09:00:00
# 10 2017-01-01 10:00:00
# 11 2017-01-01 11:00:00
# 12 2017-01-01 12:00:00
# 13 2017-01-01 13:00:00
# 14 2017-01-01 14:00:00
# 15 2017-01-01 15:00:00
# 16 2017-01-01 16:00:00
# 17 2017-01-01 17:00:00
# 18 2017-01-01 18:00:00
# 19 2017-01-01 19:00:00
# 20 2017-01-01 20:00:00
# 21 2017-01-01 21:00:00
# 22 2017-01-01 22:00:00
# 23 2017-01-01 23:00:00
# 24 2017-01-02 00:00:00
# 25 2017-01-02 01:00:00
# 26 2017-01-02 02:00:00
# 27 2017-01-02 03:00:00
# 28 2017-01-02 04:00:00
# 29 2017-01-02 05:00:00
# ..                 ...
# 70 2017-01-03 22:00:00
# 71 2017-01-03 23:00:00
# 72 2017-01-04 00:00:00
# 73 2017-01-04 01:00:00
# 74 2017-01-04 02:00:00
# 75 2017-01-04 03:00:00
# ...

# %%
df_date['year']=df_date['date'].dt.year
df_date['month']=df_date['date'].dt.month
df_date['hour']=df_date['date'].dt.hour
df_date
# Out:
#                   date  year  month  hour
# 0  2017-01-01 00:00:00  2017      1     0
# 1  2017-01-01 01:00:00  2017      1     1
# 2  2017-01-01 02:00:00  2017      1     2
# 3  2017-01-01 03:00:00  2017      1     3
# 4  2017-01-01 04:00:00  2017      1     4
# 5  2017-01-01 05:00:00  2017      1     5
# 6  2017-01-01 06:00:00  2017      1     6
# 7  2017-01-01 07:00:00  2017      1     7
# 8  2017-01-01 08:00:00  2017      1     8
# 9  2017-01-01 09:00:00  2017      1     9
# 10 2017-01-01 10:00:00  2017      1    10
# 11 2017-01-01 11:00:00  2017      1    11
# 12 2017-01-01 12:00:00  2017      1    12
# 13 2017-01-01 13:00:00  2017      1    13
# 14 2017-01-01 14:00:00  2017      1    14
# 15 2017-01-01 15:00:00  2017      1    15
# 16 2017-01-01 16:00:00  2017      1    16
# 17 2017-01-01 17:00:00  2017      1    17
# 18 2017-01-01 18:00:00  2017      1    18
# 19 2017-01-01 19:00:00  2017      1    19
# 20 2017-01-01 20:00:00  2017      1    20
# ...

# %%
df_many=pd.DataFrame()
df_many['first']=pd.Timestamp('1/1/2017'), pd.Timestamp('1/1/2017')
df_many['Second']=pd.Timestamp('10/1/2017'), pd.Timestamp('1/6/2017')
df_many
# Out:
#        first     Second
# 0 2017-01-01 2017-10-01
# 1 2017-01-01 2017-01-06

# %%
df_many['diff']=df_many['Second']-df_many['first']
df_many['diff']
# Out:
# 0   273 days
# 1     5 days
# Name: diff, dtype: timedelta64[ns]

# %%
df1=pd.DataFrame(index=df_date)
df1
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
df1['height']={2,5,6,7,4,5,9,8}
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-46-235504c4ebc6> in <module>()
# ----> 1 df1['height']={2,5,6,7,4,5,9,8}
#
# C:\Users\Ajay Acharya\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\pandas\core\frame.pyc in __setitem__(self, key, value)
#    2329         else:
#    2330             # set column
# -> 2331             self._set_item(key, value)
#    2332
#    2333     def _setitem_slice(self, key, value):
#
# C:\Users\Ajay Acharya\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\pandas\core\frame.pyc in _set_item(self, key, value)
#    2395
#    2396         self._ensure_valid_index(value)
# -> 2397         value = self._sanitize_column(key, value)
#    2398         NDFrame._set_item(self, key, value)
#    2399
#
# C:\Users\Ajay Acharya\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\pandas\core\frame.pyc in _sanitize_column(self, key, value, broadcast)
#    2566
#    2567             # turn me into an ndarray
# ...

# %%
df_dates['date']=pd.date_range('1/1/2017', periods=5 freq='H')
df=pd.DataFrame(index=df_dates)
df['height']={2,5,6,7,4,5,9,8}

df.rolling(window=3).mean()
#rolling window add previous values to next value and take mean of it
# Out:
#   File "<ipython-input-48-a512ae892ca7>", line 1
#     df_dates['date']=pd.date_range('1/1/2017', periods=5 freq='H')
#                                                             ^
# SyntaxError: invalid syntax

# %%
# interpolation: fill the missing values(Backfilling, forward fillling)
time_index_for_calculation = pd.date_range('01/01/2017', periods=5, freq='W')
df_weeks= pd.DataFrame(index=time_index_for_calculation)
df_weeks
# Out:
# Empty DataFrame
# Columns: []
# Index: [2017-01-01 00:00:00, 2017-01-08 00:00:00, 2017-01-15 00:00:00, 2017-01-22 00:00:00, 2017-01-29 00:00:00]

# %%
df_weeks['Price']=[12,85,na,na,85]
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-51-a8d1ab3fc1aa> in <module>()
# ----> 1 df_weeks['Price']=[12,85,na,na,85]
#
# NameError: name 'na' is not defined

# %%
df_weeks.interpolate?
